# %% [markdown]
# # Notebook Clase 1
# Vamos a repasar estructuras básicas de Python:
# * Listas
# * Diccionarios

# %%
# Repaso de Lista
alumnos_lista = ["Ana", "Juan", "Pedro"]
print("El primer alumno de la lista es:", alumnos_lista[0])
alumnos_lista[1] = "Mateo"

# Repaso de Diccionario
alumno_datos = {
    "nombre": "Ana",
    "edad": 22,
    "carrera": "Programación"
}

# Modificamos un dato
alumno_datos["edad"] = 23

print("Datos actualizados del alumno:")
print(alumno_datos)
# Out:
# El primer alumno de la lista es: Ana
# Datos actualizados del alumno:
# {'nombre': 'Ana', 'edad': 23, 'carrera': 'Programación'}

# %% [markdown]
# #Ejercicio 1
# ###Consigna: "Mi CV en Markdown"
# * Abran un nuevo Jupyter Notebook o Google Colab.
# * Creen una celda de texto (Markdown). Pongan su nombre como Título Principal (#).
# * Hagan una lista con 3 tecnologías que ya conozcan o materias que hayan aprobado.
# * Creen una celda de código debajo.
# * Declaren un diccionario llamado mi_perfil que contenga las claves: nombre, ciudad, y lenguaje_favorito.
# * Usen un print para mostrar un mensaje de presentación sacando los datos de ese diccionario.

# %% [markdown]
# #Ejercicio 2
# ###DESAFÍO: EL MINI-ETL (Extract, Transform, Load)
# Deberán crear un script debajo de esos datos que resuelva lo siguiente:
# * Filtro de Alerta: Recorrer los datos e imprimir un mensaje de alerta solo para los productos que tengan el stock en 0. (Ej: "Alerta: Hay que reponer Mouse").
# * Cálculo Financiero: Calcular cuál es el valor total del inventario que tenemos valorizado en dinero (es decir, multiplicar el precio por el stock de cada producto y sumar todo).
# * Imprimir el resultado final del dinero total con un mensaje claro.

# %%
# Dataset inicial
# Simulamos datos recibidos de un sistema de ventas (JSON)
datos_inventario = [
    {"id": 1, "producto": "Laptop", "precio": 1200, "stock": 5, "categoria": "Tecnología"},
    {"id": 2, "producto": "Mouse", "precio": 25, "stock": 0, "categoria": "Accesorios"},
    {"id": 3, "producto": "Silla", "precio": 150, "stock": 12, "categoria": "Mobiliario"},
    {"id": 4, "producto": "Teclado", "precio": 45, "stock": 0, "categoria": "Accesorios"},
    {"id": 5, "producto": "Monitor", "precio": 300, "stock": 3, "categoria": "Tecnología"}
]
